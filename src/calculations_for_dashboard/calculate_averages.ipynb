# %% [markdown]
# # Calculate averages for standard, variance-aware and not-variance-aware algorithms

# %%
import os
import pandas as pd

# %%
# Base path
base_path = os.path.abspath(os.path.join(os.getcwd(), "..", "..", "data", "algorithms_results"))

# Variance-aware und nicht-variance-aware Algorithmen
var_aware_algorithms = ["5_UCB-Tuned", "6_UCB-V", "9_EUCBV"]
not_var_aware_algorithms = ["7_PAC-UCB", "8_UCB-Improved"]
standard_algorithms = ["1_ETC", "2_Greedy", "3_UCB", "4_UCB-Normal"]

# Dateikombinationen
combinations = [
    "opt_ver1", "opt_ver2", "opt_ver3",
    "subopt_ver1", "subopt_ver2", "subopt_ver3"
]

# Funktion zum Berechnen des Durchschnitts und Speichern der Ergebnisse
def calculate_average_and_save(algorithms, output_file_suffix):
    for combination in combinations:
        combined_df = None

        for algorithm in algorithms:
            file_path = os.path.join(base_path, f"{algorithm}_results_{combination}.csv")
            df = pd.read_csv(file_path)

            if combined_df is None:
                combined_df = df
            else:
                combined_df.iloc[:, 1:] += df.iloc[:, 1:]  # Addiere die Werte der entsprechenden Spalten

        combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt

        output_file_path = os.path.join(base_path, f"{output_file_suffix}_results_{combination}.csv")
        combined_df.to_csv(output_file_path, index=False)

# Berechne und speichere die Durchschnittswerte für variance-aware Algorithmen
calculate_average_and_save(var_aware_algorithms, "Variance-aware UCB Variations")

# Berechne und speichere die Durchschnittswerte für nicht-variance-aware Algorithmen
calculate_average_and_save(not_var_aware_algorithms, "Not-variance-aware UCB Variations")

# Berechne und speichere die Durchschnittswerte für nicht-variance-aware Algorithmen
calculate_average_and_save(standard_algorithms, "Standard Algorithms")

print("Durchschnittswerte erfolgreich berechnet und gespeichert.")
# Out:
# Durchschnittswerte erfolgreich berechnet und gespeichert.
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0         1.0
# 1         1.0
# 2         1.0
# 3         1.0
# 4         1.0
#         ...
# 1095    100.0
# 1096    100.0
# 1097    100.0
# 1098    100.0
# 1099    100.0
# Name: Iteration, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0         1.000000
# 1         1.000000
# 2        37.333333
# 3        68.000000
# 4       271.666667
#            ...
# 1095    367.666667
# 1096    379.000000
# 1097    388.000000
# 1098    395.000000
# 1099    411.333333
# Name: Suboptimal Arms, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0           0.333333
# 1           0.333333
# 2          13.000000
# 3          28.000000
# 4         225.000000
#             ...
# 1095     2049.333333
# 1096     4039.666667
# 1097     6022.000000
# 1098     8033.666667
# 1099    10016.333333
# Name: Zeros Count, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0           1.666667
# 1           2.666667
# 2          87.000000
# 3         172.000000
# 4        1775.000000
#             ...
# 1095    17950.666667
# 1096    35960.333333
# 1097    53978.000000
# 1098    71966.333333
# 1099    89983.666667
# Name: Ones Count, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0         1.0
# 1         1.0
# 2         1.0
# 3         1.0
# 4         1.0
#         ...
# 1095    100.0
# 1096    100.0
# 1097    100.0
# 1098    100.0
# 1099    100.0
# Name: Iteration, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0           1.000000
# 1           1.000000
# 2          45.333333
# 3         100.333333
# 4         991.333333
#             ...
# 1095     7983.000000
# 1096    14028.000000
# 1097    19223.000000
# 1098    25127.333333
# 1099    28244.000000
# Name: Suboptimal Arms, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0           0.000000
# 1           0.000000
# 2          13.666667
# 3          24.666667
# 4         206.333333
#             ...
# 1095     2011.333333
# 1096     4024.333333
# 1097     6041.333333
# 1098     8052.333333
# 1099    10056.000000
# Name: Zeros Count, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0           2.000000
# 1           3.000000
# 2          86.333333
# 3         175.333333
# 4        1793.666667
#             ...
# 1095    17988.666667
# 1096    35975.666667
# 1097    53958.666667
# 1098    71947.666667
# 1099    89944.000000
# Name: Ones Count, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0         1.0
# 1         1.0
# 2         1.0
# 3         1.0
# 4         1.0
#         ...
# 1095    100.0
# 1096    100.0
# 1097    100.0
# 1098    100.0
# 1099    100.0
# Name: Iteration, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0           1.000000
# 1           1.333333
# 2          45.000000
# 3         109.333333
# 4        1209.666667
#             ...
# 1095     6807.000000
# 1096    11396.000000
# 1097    16672.000000
# 1098    20711.333333
# 1099    22975.666667
# Name: Suboptimal Arms, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0           1.333333
# 1           2.333333
# 2          52.333333
# 3         100.666667
# 4         996.000000
#             ...
# 1095     9946.333333
# 1096    19961.333333
# 1097    30000.666667
# 1098    39954.000000
# 1099    49958.333333
# Name: Zeros Count, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0           0.666667
# 1           0.666667
# 2          47.666667
# 3          99.333333
# 4        1004.000000
#             ...
# 1095    10053.666667
# 1096    20038.666667
# 1097    29999.333333
# 1098    40046.000000
# 1099    50041.666667
# Name: Ones Count, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0         1.0
# 1         1.0
# 2         1.0
# 3         1.0
# 4         1.0
#         ...
# 1095    100.0
# 1096    100.0
# 1097    100.0
# 1098    100.0
# 1099    100.0
# Name: Iteration, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0         1.000000
# 1         1.666667
# 2        46.333333
# 3        72.333333
# 4       231.000000
#            ...
# 1095    500.666667
# 1096    525.333333
# 1097    556.333333
# 1098    560.333333
# 1099    573.000000
# Name: Suboptimal Arms, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0          0.333333
# 1          0.333333
# 2         15.333333
# 3         29.666667
# 4        223.333333
#            ...
# 1095    2056.000000
# 1096    4014.666667
# 1097    6017.000000
# 1098    7979.333333
# 1099    9978.666667
# Name: Zeros Count, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0           1.666667
# 1           2.666667
# 2          84.666667
# 3         170.333333
# 4        1776.666667
#             ...
# 1095    17944.000000
# 1096    35985.333333
# 1097    53983.000000
# 1098    72020.666667
# 1099    90021.333333
# Name: Ones Count, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0         1.0
# 1         1.0
# 2         1.0
# 3         1.0
# 4         1.0
#         ...
# 1095    100.0
# 1096    100.0
# 1097    100.0
# 1098    100.0
# 1099    100.0
# Name: Iteration, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0           1.000000
# 1           2.000000
# 2          68.666667
# 3         134.000000
# 4         906.333333
#             ...
# 1095     8863.000000
# 1096    18217.666667
# 1097    23686.333333
# 1098    27183.333333
# 1099    31053.666667
# Name: Suboptimal Arms, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0           0.333333
# 1           0.333333
# 2          10.000000
# 3          17.666667
# 4         204.666667
#             ...
# 1095     2028.000000
# 1096     4048.666667
# 1097     6084.666667
# 1098     8123.666667
# 1099    10138.000000
# Name: Zeros Count, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0           1.666667
# 1           2.666667
# 2          90.000000
# 3         182.333333
# 4        1795.333333
#             ...
# 1095    17972.000000
# 1096    35951.333333
# 1097    53915.333333
# 1098    71876.333333
# 1099    89862.000000
# Name: Ones Count, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0         1.0
# 1         1.0
# 2         1.0
# 3         1.0
# 4         1.0
#         ...
# 1095    100.0
# 1096    100.0
# 1097    100.0
# 1098    100.0
# 1099    100.0
# Name: Iteration, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0           1.000000
# 1           1.666667
# 2          60.666667
# 3         111.333333
# 4        1047.333333
#             ...
# 1095     6797.666667
# 1096    12578.000000
# 1097    18481.333333
# 1098    23329.000000
# 1099    25518.000000
# Name: Suboptimal Arms, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0           0.666667
# 1           1.000000
# 2          45.666667
# 3          99.666667
# 4        1016.666667
#             ...
# 1095    10054.333333
# 1096    20075.000000
# 1097    30100.666667
# 1098    40093.666667
# 1099    50120.000000
# Name: Zeros Count, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0           1.333333
# 1           2.000000
# 2          54.333333
# 3         100.333333
# 4         983.333333
#             ...
# 1095     9945.666667
# 1096    19925.000000
# 1097    29899.333333
# 1098    39906.333333
# 1099    49880.000000
# Name: Ones Count, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0         1.0
# 1         1.0
# 2         1.0
# 3         1.0
# 4         1.0
#         ...
# 1095    100.0
# 1096    100.0
# 1097    100.0
# 1098    100.0
# 1099    100.0
# Name: Iteration, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0         1.0
# 1         1.0
# 2        26.5
# 3        47.0
# 4       243.5
#         ...
# 1095    475.0
# 1096    490.0
# 1097    495.0
# 1098    498.5
# 1099    498.5
# Name: Suboptimal Arms, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0           0.5
# 1           0.5
# 2          12.0
# 3          24.5
# 4         232.5
#          ...
# 1095     2104.0
# 1096     4051.5
# 1097     6058.0
# 1098     8060.5
# 1099    10019.0
# Name: Zeros Count, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0           1.5
# 1           2.5
# 2          88.0
# 3         175.5
# 4        1767.5
#          ...
# 1095    17896.0
# 1096    35948.5
# 1097    53942.0
# 1098    71939.5
# 1099    89981.0
# Name: Ones Count, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0         1.0
# 1         1.0
# 2         1.0
# 3         1.0
# 4         1.0
#         ...
# 1095    100.0
# 1096    100.0
# 1097    100.0
# 1098    100.0
# 1099    100.0
# Name: Iteration, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0           1.0
# 1           1.0
# 2          26.0
# 3          53.0
# 4         492.5
#          ...
# 1095     3200.0
# 1096     6201.0
# 1097     8253.0
# 1098    12811.0
# 1099    15961.0
# Name: Suboptimal Arms, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0           0.0
# 1           0.0
# 2          10.5
# 3          21.0
# 4         203.0
#          ...
# 1095     2026.0
# 1096     4076.5
# 1097     6109.5
# 1098     8152.5
# 1099    10165.0
# Name: Zeros Count, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0           2.0
# 1           3.0
# 2          89.5
# 3         179.0
# 4        1797.0
#          ...
# 1095    17974.0
# 1096    35923.5
# 1097    53890.5
# 1098    71847.5
# 1099    89835.0
# Name: Ones Count, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0         1.0
# 1         1.0
# 2         1.0
# 3         1.0
# 4         1.0
#         ...
# 1095    100.0
# 1096    100.0
# 1097    100.0
# 1098    100.0
# 1099    100.0
# Name: Iteration, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0           1.0
# 1           1.0
# 2          26.0
# 3          45.5
# 4         483.0
#          ...
# 1095    13652.0
# 1096    25571.5
# 1097    37098.0
# 1098    47374.0
# 1099    57805.0
# Name: Suboptimal Arms, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0           1.0
# 1           2.0
# 2          47.0
# 3         105.0
# 4         997.5
#          ...
# 1095    10090.5
# 1096    20177.0
# 1097    30338.5
# 1098    40367.5
# 1099    50489.0
# Name: Zeros Count, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0           1.0
# 1           1.0
# 2          53.0
# 3          95.0
# 4        1002.5
#          ...
# 1095     9909.5
# 1096    19823.0
# 1097    29661.5
# 1098    39632.5
# 1099    49511.0
# Name: Ones Count, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0         1.0
# 1         1.0
# 2         1.0
# 3         1.0
# 4         1.0
#         ...
# 1095    100.0
# 1096    100.0
# 1097    100.0
# 1098    100.0
# 1099    100.0
# Name: Iteration, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0         1.0
# 1         2.0
# 2        26.0
# 3        48.0
# 4       201.0
#         ...
# 1095    428.5
# 1096    477.5
# 1097    514.5
# 1098    514.5
# 1099    514.5
# Name: Suboptimal Arms, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0          0.0
# 1          0.5
# 2          9.0
# 3         23.0
# 4        214.5
#          ...
# 1095    2019.0
# 1096    4032.0
# 1097    6040.5
# 1098    7990.5
# 1099    9955.0
# Name: Zeros Count, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0           2.0
# 1           2.5
# 2          91.0
# 3         177.0
# 4        1785.5
#          ...
# 1095    17981.0
# 1096    35968.0
# 1097    53959.5
# 1098    72009.5
# 1099    90045.0
# Name: Ones Count, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0         1.0
# 1         1.0
# 2         1.0
# 3         1.0
# 4         1.0
#         ...
# 1095    100.0
# 1096    100.0
# 1097    100.0
# 1098    100.0
# 1099    100.0
# Name: Iteration, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0           1.0
# 1           2.0
# 2          74.5
# 3         149.5
# 4        1456.0
#          ...
# 1095     8504.0
# 1096    14875.5
# 1097    22587.5
# 1098    28809.5
# 1099    35841.0
# Name: Suboptimal Arms, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0           0.5
# 1           0.5
# 2          17.0
# 3          27.5
# 4         198.5
#          ...
# 1095     2069.5
# 1096     4095.5
# 1097     6159.0
# 1098     8238.0
# 1099    10277.5
# Name: Zeros Count, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0           1.5
# 1           2.5
# 2          83.0
# 3         172.5
# 4        1801.5
#          ...
# 1095    17930.5
# 1096    35904.5
# 1097    53841.0
# 1098    71762.0
# 1099    89722.5
# Name: Ones Count, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0         1.0
# 1         1.0
# 2         1.0
# 3         1.0
# 4         1.0
#         ...
# 1095    100.0
# 1096    100.0
# 1097    100.0
# 1098    100.0
# 1099    100.0
# Name: Iteration, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0           1.0
# 1           2.0
# 2          75.5
# 3         150.0
# 4        1544.5
#          ...
# 1095     5367.0
# 1096     8842.5
# 1097    10814.5
# 1098    13237.0
# 1099    13592.5
# Name: Suboptimal Arms, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0           0.5
# 1           0.5
# 2          44.0
# 3          89.5
# 4        1044.0
#          ...
# 1095     9983.0
# 1096    19926.0
# 1097    30011.0
# 1098    40104.0
# 1099    50109.0
# Name: Zeros Count, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0           1.5
# 1           2.5
# 2          56.0
# 3         110.5
# 4         956.0
#          ...
# 1095    10017.0
# 1096    20074.0
# 1097    29989.0
# 1098    39896.0
# 1099    49891.0
# Name: Ones Count, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:27: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0            3.0
# 1            5.0
# 2          172.0
# 3          345.0
# 4         3476.0
#           ...
# 1095     35904.0
# 1096     71713.0
# 1097    107599.0
# 1098    143538.0
# 1099    179384.0
# Name: Total Reward, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] += df.iloc[:, 1:]  # Addiere die Werte der entsprechenden Spalten
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:27: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 1095   NaN
# 1096   NaN
# 1097   NaN
# 1098   NaN
# 1099   NaN
# Name: Suboptimal Arms Count, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] += df.iloc[:, 1:]  # Addiere die Werte der entsprechenden Spalten
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0         1.0
# 1         1.0
# 2         1.0
# 3         1.0
# 4         1.0
#         ...
# 1095    100.0
# 1096    100.0
# 1097    100.0
# 1098    100.0
# 1099    100.0
# Name: Iteration, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0           0.25
# 1           0.50
# 2          23.50
# 3          46.50
# 4         435.50
#           ...
# 1095     4004.75
# 1096     8030.25
# 1097    12128.50
# 1098    16147.25
# 1099    20206.25
# Name: Zeros Count, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0           1.75
# 1           2.50
# 2          76.50
# 3         153.50
# 4        1564.50
#           ...
# 1095    15995.25
# 1096    31969.75
# 1097    47871.50
# 1098    63852.75
# 1099    79793.75
# Name: Ones Count, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:27: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0            4.0
# 1            6.0
# 2          188.0
# 3          369.0
# 4         3602.0
#           ...
# 1095     36070.0
# 1096     72121.0
# 1097    108100.0
# 1098    144156.0
# 1099    180230.0
# Name: Total Reward, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] += df.iloc[:, 1:]  # Addiere die Werte der entsprechenden Spalten
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:27: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 1095   NaN
# 1096   NaN
# 1097   NaN
# 1098   NaN
# 1099   NaN
# Name: Suboptimal Arms Count, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] += df.iloc[:, 1:]  # Addiere die Werte der entsprechenden Spalten
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0         1.0
# 1         1.0
# 2         1.0
# 3         1.0
# 4         1.0
#         ...
# 1095    100.0
# 1096    100.0
# 1097    100.0
# 1098    100.0
# 1099    100.0
# Name: Iteration, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0           0.75
# 1           0.75
# 2          18.25
# 3          40.25
# 4         409.50
#           ...
# 1095     3988.00
# 1096     7977.50
# 1097    11967.00
# 1098    15959.50
# 1099    19950.25
# Name: Zeros Count, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0           1.25
# 1           2.25
# 2          81.75
# 3         159.75
# 4        1590.50
#           ...
# 1095    16012.00
# 1096    32022.50
# 1097    48033.00
# 1098    64040.50
# 1099    80049.75
# Name: Ones Count, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:27: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0            2.0
# 1            4.0
# 2          104.0
# 3          211.0
# 4         1995.0
#           ...
# 1095     20156.0
# 1096     40141.0
# 1097     59908.0
# 1098     79855.0
# 1099    100043.0
# Name: Total Reward, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] += df.iloc[:, 1:]  # Addiere die Werte der entsprechenden Spalten
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:27: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 1095   NaN
# 1096   NaN
# 1097   NaN
# 1098   NaN
# 1099   NaN
# Name: Suboptimal Arms Count, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] += df.iloc[:, 1:]  # Addiere die Werte der entsprechenden Spalten
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0         1.0
# 1         1.0
# 2         1.0
# 3         1.0
# 4         1.0
#         ...
# 1095    100.0
# 1096    100.0
# 1097    100.0
# 1098    100.0
# 1099    100.0
# Name: Iteration, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0           0.50
# 1           0.50
# 2          48.25
# 3          96.00
# 4        1003.00
#           ...
# 1095    10001.00
# 1096    20024.25
# 1097    30076.25
# 1098    40110.75
# 1099    50016.00
# Name: Zeros Count, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0           1.50
# 1           2.50
# 2          51.75
# 3         104.00
# 4         997.00
#           ...
# 1095     9999.00
# 1096    19975.75
# 1097    29923.75
# 1098    39889.25
# 1099    49984.00
# Name: Ones Count, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:27: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0            3.0
# 1            5.0
# 2          165.0
# 3          343.0
# 4         3469.0
#           ...
# 1095     35900.0
# 1096     71860.0
# 1097    107872.0
# 1098    143866.0
# 1099    179799.0
# Name: Total Reward, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] += df.iloc[:, 1:]  # Addiere die Werte der entsprechenden Spalten
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:27: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 1095   NaN
# 1096   NaN
# 1097   NaN
# 1098   NaN
# 1099   NaN
# Name: Suboptimal Arms Count, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] += df.iloc[:, 1:]  # Addiere die Werte der entsprechenden Spalten
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0         1.0
# 1         1.0
# 2         1.0
# 3         1.0
# 4         1.0
#         ...
# 1095    100.0
# 1096    100.0
# 1097    100.0
# 1098    100.0
# 1099    100.0
# Name: Iteration, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0           0.75
# 1           1.00
# 2          25.00
# 3          45.75
# 4         437.00
#           ...
# 1095     4041.25
# 1096     8043.50
# 1097    12073.25
# 1098    16062.00
# 1099    20076.25
# Name: Zeros Count, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0           1.25
# 1           2.00
# 2          75.00
# 3         154.25
# 4        1563.00
#           ...
# 1095    15958.75
# 1096    31956.50
# 1097    47926.75
# 1098    63938.00
# 1099    79923.75
# Name: Ones Count, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:27: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0            4.0
# 1            6.0
# 2          175.0
# 3          359.0
# 4         3613.0
#           ...
# 1095     35976.0
# 1096     71910.0
# 1097    107788.0
# 1098    143693.0
# 1099    179590.0
# Name: Total Reward, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] += df.iloc[:, 1:]  # Addiere die Werte der entsprechenden Spalten
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:27: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 1095   NaN
# 1096   NaN
# 1097   NaN
# 1098   NaN
# 1099   NaN
# Name: Suboptimal Arms Count, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] += df.iloc[:, 1:]  # Addiere die Werte der entsprechenden Spalten
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0         1.0
# 1         1.0
# 2         1.0
# 3         1.0
# 4         1.0
#         ...
# 1095    100.0
# 1096    100.0
# 1097    100.0
# 1098    100.0
# 1099    100.0
# Name: Iteration, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0           0.75
# 1           1.00
# 2          24.25
# 3          44.25
# 4         400.00
#           ...
# 1095     4028.25
# 1096     8088.25
# 1097    12178.00
# 1098    16178.25
# 1099    20250.25
# Name: Zeros Count, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0           1.25
# 1           2.00
# 2          75.75
# 3         155.75
# 4        1600.00
#           ...
# 1095    15971.75
# 1096    31911.75
# 1097    47822.00
# 1098    63821.75
# 1099    79749.75
# Name: Ones Count, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:27: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0            1.0
# 1            3.0
# 2          106.0
# 3          205.0
# 4         1950.0
#           ...
# 1095     20110.0
# 1096     40025.0
# 1097     60062.0
# 1098     80134.0
# 1099    100146.0
# Name: Total Reward, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] += df.iloc[:, 1:]  # Addiere die Werte der entsprechenden Spalten
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:27: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 1095   NaN
# 1096   NaN
# 1097   NaN
# 1098   NaN
# 1099   NaN
# Name: Suboptimal Arms Count, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] += df.iloc[:, 1:]  # Addiere die Werte der entsprechenden Spalten
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0         1.0
# 1         1.0
# 2         1.0
# 3         1.0
# 4         1.0
#         ...
# 1095    100.0
# 1096    100.0
# 1097    100.0
# 1098    100.0
# 1099    100.0
# Name: Iteration, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0           1.75
# 1           2.00
# 2          50.50
# 3         100.50
# 4        1024.50
#           ...
# 1095     9981.00
# 1096    19994.00
# 1097    30003.75
# 1098    39952.50
# 1099    49967.00
# Name: Zeros Count, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_38040/153020920.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0           0.25
# 1           1.00
# 2          49.50
# 3          99.50
# 4         975.50
#           ...
# 1095    10019.00
# 1096    20006.00
# 1097    29996.25
# 1098    40047.50
# 1099    50033.00
# Name: Ones Count, Length: 1100, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_df.iloc[:, 1:] /= len(algorithms)  # Berechne den Durchschnitt
